# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix, precision_recall_curve
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from tensorflow import keras

# %%
data=pd.read_csv('Database_propre.csv')

prediction=data['prediction']
data= data.drop('prediction', axis=1)

# %%
# Compter les nombres 
def counts_litige(x):
    c=0
    for e in x:
        if e==1:
            c=c+1
    return(c) 

print("nombre de litiges=" , counts_litige(prediction))
print("nombre total d'observation=", prediction.size)
# Out:
# nombre de litiges= 8244
# nombre total d'observation= 644019

# %%
#plot bar plot 

plt.hist(prediction,bins=2)
plt.xticks([0,1])
plt.title('Répartition des classes')
plt.show()
print(f'Il n y a seulement {counts_litige(prediction)} litiges soit seulement {counts_litige(prediction)/prediction.size} de l ensemble des observatons')
# Out:
# Il n y a seulement 8244 litiges soit seulement 0.01280086457076577 de l ensemble des observatons
